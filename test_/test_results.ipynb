# %%
# %run testgv

# %%
data = importdexcom('test_file.csv')

# %%
print('interdaysd is: ' + str(interdaysd(data)))
print('interdaycv is: ' + str(interdaycv(data)))
print('intradaysd is: ' + str(intradaysd(data)))
print('intradaycv is: ' + str(intradaycv(data)))
print('TOR is: ' + str(TOR(data)))
print('TIR is: ' + str(TIR(data)))
print('POR is: ' + str(POR(data)))
print('MGE is: ' + str(MGE(data)))
print('MGN is: ' + str(MGN(data)))
print('MAGE is: ' + str(MAGE(data)))
print('MODD is: ' + str(MODD(data)))
print('J_index is: ' + str(J_index(data)))
print('LBGI is: ' + str(LBGI(data)))
print('HBGI is: ' + str(HBGI(data)))
print('ADRR is: ' + str(ADRR(data)))
print('CONGA24 is: ' + str(CONGA24(data)))
print('GMI is: ' + str(GMI(data)))
print('eA1c is: ' + str(eA1c(data)))
print('summary is: ' + str(summary(data)))
# Out:
# interdaysd is: 28.799063508925446
# interdaycv is: 25.73624640632627
# intradaysd is: (46.6267582402342, 38.49949692558805, 26.519332340419986)
# intradaycv is: (21.444099179199764, 21.175300957094716, 8.137154426462626)
# TOR is: 1985
# TIR is: 8750
# POR is: 18.49091755938519
# MGE is: index      1159.284635
# Glucose     135.423174
# dtype: float64
# MGN is: index      1068.148000
# Glucose     106.564571
# dtype: float64
# MAGE is: 48.715
# MODD is: 27.667695370831257
# J_index is: 19.796449284660316
# LBGI is: 0.9095514600407604
# HBGI is: 0.9429935347767346
# ADRR is: 21.343472829647837
# CONGA24 is: 17.433750765189647
# GMI is: 5.986666939916162
# eA1c is: 5.526159993118995
# summary is: (111.90079180251514, 105.0, 49.0, 261.0, 97.0, 119.0)

# %%
plotglucosebounds(data)

# %%
plotglucosesd(data)

# %%
plotglucosesmooth(data)
